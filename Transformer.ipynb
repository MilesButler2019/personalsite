# %%
import numpy as np

class Layer:
    def __init__(self,inputs,weights):

        # Kaiming Initalization to help with vanishing gradient problem for non-linear activation functionss like Relu https://paperswithcode.com/method/he-initialization
        #self.weights = np.random.normal(loc = 0,scale=1,weights*inputs) 

        self.weights = np.random(weights, inputs)
        self.bias = np.zeros((self.weights,1))

    def forward(self,W_prev):
        self.W_prev = W_prev
        self.weights = np.dot(self.weights,self.W_prev) + self.bias
        
    
    
    def backprop(self):

# %%
class FFNN:
